# %% [markdown]
# ### Importing Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### Importing the Data

# %%
# df = pd.read_csv('..\Data\Train_TEC_mar17.csv')
df = pd.read_csv('../Data/TotalWithMissing.csv')

# %%
df.head()
# Out:
#    Date  Month  Year      Time        LT       TEC
# 0     1      3  2017  0.016389  5.311333  2.067562
# 1     1      3  2017  0.049722  5.344670  2.082707
# 2     1      3  2017  0.083056  5.378006  2.004272
# 3     1      3  2017  0.116389  5.411343  1.736569
# 4     1      3  2017  0.149722  5.444679  1.758503

# %% [markdown]
# #### Dropping Useless columns

# %%
df.drop(["Date","Month","Year","Time","LT"], axis = 1, inplace = True)

# %%
df.fillna(0.0, inplace=True)
df.tail()
# Out:
#        TEC
# 22315  0.0
# 22316  0.0
# 22317  0.0
# 22318  0.0
# 22319  0.0

# %% [markdown]
# #### Converting it into a ndarray

# %%
training_set = df.iloc[:,:].values

# %%
type(training_set), training_set.shape
# Out:
# (numpy.ndarray, (22320, 1))

# %% [markdown]
# #### Plotting the Data

# %%
plt.figure(figsize=(20,10))

plt.plot(training_set, label = 'TEC Values')
plt.show()

# %% [markdown]
# #### Making Data Sequential for look back

# %%
def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

sc = MinMaxScaler()

training_data = sc.fit_transform(training_set)

seq_length = 4
x, y = sliding_windows(training_data, seq_length)

train_size = int(len(y) * 0.20)
test_size = len(y) - train_size

dataX = Variable(torch.Tensor(np.array(x)))
dataY = Variable(torch.Tensor(np.array(y)))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])))

testX = Variable(torch.Tensor(np.array(x[train_size:len(x)])))
testY = Variable(torch.Tensor(np.array(y[train_size:len(y)])))

# %%
training_data[-5:],x[0].shape, x[0], x[1], y
# Out:
# (array([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]]),
#  (4, 1),
#  array([[0.04918105],
#         [0.0495413 ],
#         [0.04767557],
#         [0.04130773]]),
#  array([[0.0495413 ],
#         [0.04767557],
#         [0.04130773],
#         [0.04182947]]),
#  array([[0.04182947],
#         [0.03685276],
#         [0.04142007],
#         ...,
#         [0.        ],
#         [0.        ],
#         [0.        ]]))

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %%
# num_epochs = 1000
num_epochs = 100
learning_rate = 0.01

input_size = 1
hidden_size = 2
num_layers = 1

num_classes = 1

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

criterion = torch.nn.MSELoss()   
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    
    loss = criterion(outputs, trainY)
    
    loss.backward()
    
    optimizer.step()
    if epoch % 1 == 0:
      print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
# Out:
# Epoch: 0, loss: 1.06732
# Epoch: 1, loss: 1.03838
# Epoch: 2, loss: 1.00875
# Epoch: 3, loss: 0.97840
# Epoch: 4, loss: 0.94733
# Epoch: 5, loss: 0.91550
# Epoch: 6, loss: 0.88290
# Epoch: 7, loss: 0.84950
# Epoch: 8, loss: 0.81530
# Epoch: 9, loss: 0.78029
# Epoch: 10, loss: 0.74447
# Epoch: 11, loss: 0.70786
# Epoch: 12, loss: 0.67050
# Epoch: 13, loss: 0.63242
# Epoch: 14, loss: 0.59372
# Epoch: 15, loss: 0.55448
# Epoch: 16, loss: 0.51485
# Epoch: 17, loss: 0.47499
# Epoch: 18, loss: 0.43510
# Epoch: 19, loss: 0.39544
# Epoch: 20, loss: 0.35627
# Epoch: 21, loss: 0.31791
# Epoch: 22, loss: 0.28070
# Epoch: 23, loss: 0.24500
# Epoch: 24, loss: 0.21118
# Epoch: 25, loss: 0.17959
# Epoch: 26, loss: 0.15057
# Epoch: 27, loss: 0.12442
# Epoch: 28, loss: 0.10138
# Epoch: 29, loss: 0.08163
# Epoch: 30, loss: 0.06525
# Epoch: 31, loss: 0.05224
# Epoch: 32, loss: 0.04251
# Epoch: 33, loss: 0.03585
# Epoch: 34, loss: 0.03196
# Epoch: 35, loss: 0.03047
# Epoch: 36, loss: 0.03093
# Epoch: 37, loss: 0.03284
# Epoch: 38, loss: 0.03570
# Epoch: 39, loss: 0.03901
# Epoch: 40, loss: 0.04234
# Epoch: 41, loss: 0.04530
# Epoch: 42, loss: 0.04763
# Epoch: 43, loss: 0.04913
# Epoch: 44, loss: 0.04973
# Epoch: 45, loss: 0.04942
# Epoch: 46, loss: 0.04828
# Epoch: 47, loss: 0.04644
# Epoch: 48, loss: 0.04405
# Epoch: 49, loss: 0.04130
# Epoch: 50, loss: 0.03836
# Epoch: 51, loss: 0.03540
# Epoch: 52, loss: 0.03255
# Epoch: 53, loss: 0.02992
# Epoch: 54, loss: 0.02761
# Epoch: 55, loss: 0.02564
# Epoch: 56, loss: 0.02404
# Epoch: 57, loss: 0.02279
# Epoch: 58, loss: 0.02186
# Epoch: 59, loss: 0.02121
# Epoch: 60, loss: 0.02078
# Epoch: 61, loss: 0.02050
# Epoch: 62, loss: 0.02032
# Epoch: 63, loss: 0.02017
# Epoch: 64, loss: 0.02003
# Epoch: 65, loss: 0.01983
# Epoch: 66, loss: 0.01957
# Epoch: 67, loss: 0.01921
# Epoch: 68, loss: 0.01877
# Epoch: 69, loss: 0.01823
# Epoch: 70, loss: 0.01761
# Epoch: 71, loss: 0.01692
# Epoch: 72, loss: 0.01619
# Epoch: 73, loss: 0.01543
# Epoch: 74, loss: 0.01466
# Epoch: 75, loss: 0.01391
# Epoch: 76, loss: 0.01318
# Epoch: 77, loss: 0.01248
# Epoch: 78, loss: 0.01184
# Epoch: 79, loss: 0.01124
# Epoch: 80, loss: 0.01070
# Epoch: 81, loss: 0.01020
# Epoch: 82, loss: 0.00974
# Epoch: 83, loss: 0.00931
# Epoch: 84, loss: 0.00890
# Epoch: 85, loss: 0.00851
# Epoch: 86, loss: 0.00813
# Epoch: 87, loss: 0.00776
# Epoch: 88, loss: 0.00738
# Epoch: 89, loss: 0.00700
# Epoch: 90, loss: 0.00663
# Epoch: 91, loss: 0.00625
# Epoch: 92, loss: 0.00589
# Epoch: 93, loss: 0.00553
# Epoch: 94, loss: 0.00518
# Epoch: 95, loss: 0.00486
# Epoch: 96, loss: 0.00455
# Epoch: 97, loss: 0.00426
# Epoch: 98, loss: 0.00400
# Epoch: 99, loss: 0.00375

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)


plt.figure(figsize=(20,10))

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('LSTM')
plt.show()

# %%
train_predict.shape
# Out:
# torch.Size([22315, 1])

# %%
dataY_plot.shape
# Out:
# (14395, 1)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(dataY_plot, data_predict))

rms
# Out:
# 0.7234442049379023

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
scaler = MinMaxScaler()
scaler.fit(df)
train_fcast = df
scaler.fit(train_fcast)
train_fcast = scaler.transform(train_fcast)
n_input = 7200
n_features = 1
generator = TimeseriesGenerator(train_fcast, train_fcast, length=n_input, batch_size=6)
lstm.fit_generator(generator,epochs=90)
pred_list = []  
batch = train_fcast[-n_input:].reshape((1, n_input, n_features))
for i in range(n_input):
    pred_list.append(lstm.predict(batch)[0])      
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-56477815c264> in <module>
#       8 n_features = 1
#       9 generator = TimeseriesGenerator(train_fcast, train_fcast, length=n_input, batch_size=6)
# ---> 10 lstm.fit_generator(generator,epochs=90)
#      11 pred_list = []
#      12 batch = train_fcast[-n_input:].reshape((1, n_input, n_features))
#
# ~\Miniconda3\envs\TEC\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     583                 return modules[name]
#     584         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 585             type(self).__name__, name))
#     586
#     587     def __setattr__(self, name, value):
#
# AttributeError: 'LSTM' object has no attribute 'fit_generator'
